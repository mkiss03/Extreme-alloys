# %% [markdown]
# # Extreme Alloys - Data Exploration
#
# This notebook is for exploring alloy composition data and extreme condition behavior.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Load Data
#
# TODO: Load alloy composition and creep test data from Materials Project or NIMS

# %%
# Load data here
# df = pd.read_csv('../raw/alloy_data.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# EDA code here
